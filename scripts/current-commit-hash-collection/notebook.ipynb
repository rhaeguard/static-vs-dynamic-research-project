# %%
import pandas as pd

# %%
all_projects = {}

with open("out.txt") as file:
    for line in file:
        if len(line.strip()) > 0:
            lang, project, commit_hash = line.strip().split("/")
            all_projects[project] = commit_hash

# %%
def construct_dataframe(lang: str):
    # read from csv dump
    df = pd.read_csv("%s.csv" % lang)
    # only keep these columns
    df = df[["Project Name", "Github URL", "Github Stars","Language %"]]
    # insert the language as the first column
    df.insert(0, "Language", lang)

    # map the hashes
    project_names = df["Project Name"].tolist()
    project_hashes = []
    for pn in project_names:
        project_hashes.append(all_projects[pn])

    lch = pd.DataFrame(project_hashes, columns=["Last Commit Hash"])
    # add the new column to df
    return pd.concat([df, lch], axis=1)

def construct_dataframe_for_all_langs():
    langs = ("go", "js", "kotlin", "python", "ruby", "scala")
    dfs = []
    for lang in langs:
        dfs.append(construct_dataframe(lang))
    return pd.concat(dfs).reset_index(drop=True)

# %%
construct_dataframe_for_all_langs()
# Out:
#    Language            Project Name  \
# 0        go              kubernetes
# 1        go                    moby
# 2        go                    hugo
# 3        go                     gin
# 4        go                     frp
# 5        go              v2ray-core
# 6        go                    gogs
# 7        go              prometheus
# 8        go                    etcd
# 9        go                 traefik
# 10       js                     vue
# 11       js                   react
# 12       js              angular.js
# 13       js        create-react-app
# 14       js                three.js
# 15       js                  jquery
# 16       js                    atom
# 17       js                Chart.js
# 18       js                 express
# 19       js                  lodash
# 20   kotlin     shadowsocks-android
# 21   kotlin              leakcanary
# 22   kotlin                 iosched
# 23   kotlin        material-dialogs
# 24   kotlin          MaterialDrawer
# 25   kotlin               tachiyomi
# 26   kotlin  recyclerview-animators
# 27   kotlin                AppIntro
# 28   kotlin      kotlinx.coroutines
# 29   kotlin                    ktor
# 30   python              youtube-dl
# 31   python                  scrapy
# 32   python                  django
# 33   python                   flask
# 34   python                   keras
# 35   python                  httpie
# 36   python                 ansible
# 37   python            scikit-learn
# 38   python                requests
# 39   python            transformers
# 40     ruby                   rails
# 41     ruby                  huginn
# 42     ruby                    brew
# 43     ruby    metasploit-framework
# 44     ruby                 vagrant
# 45     ruby                  devise
# 46     ruby                 sinatra
# 47     ruby               CocoaPods
# 48     ruby              capistrano
# 49     ruby                 rubocop
# 50    scala                 finagle
# 51    scala        bfg-repo-cleaner
# 52    scala                  scalaz
# 53    scala                   dotty
# 54    scala                     sbt
# 55    scala                scala-js
# 56    scala                marathon
# 57    scala            scala-native
# 58    scala                   BigDL
# 59    scala                  breeze
#
#                                            Github URL  Github Stars  \
# 0            https://github.com/kubernetes/kubernetes         75420
# 1                        https://github.com/moby/moby         59854
# 2                    https://github.com/gohugoio/hugo         50738
# 3                    https://github.com/gin-gonic/gin         46554
# 4                     https://github.com/fatedier/frp         43950
# 5                 https://github.com/v2ray/v2ray-core         36765
# 6                        https://github.com/gogs/gogs         36624
# 7            https://github.com/prometheus/prometheus         35860
# 8                     https://github.com/etcd-io/etcd         35225
# 9                  https://github.com/traefik/traefik         33101
# 10                       https://github.com/vuejs/vue        180846
# 11                  https://github.com/facebook/react        165487
# 12              https://github.com/angular/angular.js         59588
# 13       https://github.com/facebook/create-react-app         86724
# 14                 https://github.com/mrdoob/three.js         68495
# 15                   https://github.com/jquery/jquery         54653
# 16                       https://github.com/atom/atom         54622
# 17                https://github.com/chartjs/Chart.js         52546
# 18               https://github.com/expressjs/express         52617
# 19                   https://github.com/lodash/lodash         48634
# 20  https://github.com/shadowsocks/shadowsocks-and...         31277
# 21               https://github.com/square/leakcanary         25938
# 22                  https://github.com/google/iosched         20349
# 23     https://github.com/afollestad/material-dialogs         18670
# 24         https://github.com/mikepenz/MaterialDrawer         11335
# 25          https://github.com/tachiyomiorg/tachiyomi         10597
# 26  https://github.com/wasabeef/recyclerview-anima...         10560
# 27               https://github.com/AppIntro/AppIntro          9714
# 28       https://github.com/Kotlin/kotlinx.coroutines          9107
# 29                     https://github.com/ktorio/ktor          8130
# 30             https://github.com/ytdl-org/youtube-dl         91743
# 31                   https://github.com/scrapy/scrapy         40268
# 32                   https://github.com/django/django         56312
# 33                   https://github.com/pallets/flask         54241
# 34                https://github.com/keras-team/keras         50892
# 35                   https://github.com/httpie/httpie         50208
# 36                 https://github.com/ansible/ansible         47278
# 37       https://github.com/scikit-learn/scikit-learn         44924
# 38                    https://github.com/psf/requests         44822
# 39        https://github.com/huggingface/transformers         42631
# 40                     https://github.com/rails/rails         47813
# 41                   https://github.com/huginn/huginn         31084
# 42                   https://github.com/Homebrew/brew         27240
# 43     https://github.com/rapid7/metasploit-framework         23458
# 44               https://github.com/hashicorp/vagrant         21660
# 45               https://github.com/heartcombo/devise         21512
# 46                 https://github.com/sinatra/sinatra         11271
# 47             https://github.com/CocoaPods/CocoaPods         13089
# 48           https://github.com/capistrano/capistrano         11782
# 49                 https://github.com/rubocop/rubocop         11344
# 50                 https://github.com/twitter/finagle          7905
# 51         https://github.com/rtyley/bfg-repo-cleaner          7398
# 52                   https://github.com/scalaz/scalaz          4444
# 53                  https://github.com/lampepfl/dotty          4380
# 54                         https://github.com/sbt/sbt          4294
# 55               https://github.com/scala-js/scala-js          4131
# 56             https://github.com/mesosphere/marathon          3995
# 57       https://github.com/scala-native/scala-native          3961
# 58           https://github.com/intel-analytics/BigDL          3708
# 59                 https://github.com/scalanlp/breeze          3226
#
#     Language % Last Commit Hash
# 0         96.7      b0abe89ae25
# 1         96.8       dd14dbd53d
# 2         99.1         7b4ade56
# 3         99.6          bfc8ca2
# 4         98.2          fbaa5f8
# 5         97.5         5dffca84
# 6         90.6         509a3922
# 7         89.2        431ea75a1
# 8         96.3        dfb03aba0
# 9         91.1         cb4fb973
# 10        97.7         6ec33f70
# 11        95.3        d77851899
# 12        98.1        02545a8ba
# 13        98.3         2d1829ea
# 14        99.2       9bf1555683
# 15        93.9         a684e6ba
# 16        88.1        10f7d454e
# 17        99.2         ac0a86b9
# 18       100.0         50893685
# 19       100.0        2f79053d7
# 20        96.5         1437b43d
# 21       100.0         e0057cf5
# 22        96.8        b428d2be4
# 23       100.0         709cfee9
# 24        99.0         78357c4f
# 25       100.0         b2d69713
# 26        99.6          6c5c774
# 27        98.4          85350b2
# 28        98.6         5eca49cf
# 29       100.0        429ed3c97
# 30        99.6        70d0d4f9b
# 31        99.7         5a75b14a
# 32        97.0       da542ccab6
# 33        99.9         85b8fab2
# 34        97.6         68d25714
# 35        95.9          fc45bf0
# 36        88.1       05662fd2ab
# 37        97.7        877c6e6db
# 38        99.7         2c2138e8
# 39        93.9        76800fb8e
# 40        95.4       0ff395e1b1
# 41        88.8         4d17829c
# 42        93.5        b122288f5
# 43        94.6       4239c33143
# 44        95.9        9c45f7d25
# 45        97.2         5d5636f0
# 46        99.4         cf404526
# 47       100.0        123f2d02f
# 48        95.6         f5a16779
# 49        99.9        02419b84a
# 50        94.7        2f0a88956
# 51        99.9          e7cdc46
# 52        98.5        3e96b0758
# 53        97.1       86b4d627af
# 54        96.4        59130d470
# 55        99.9        8a0655b2d
# 56        88.8        9ee9f3ceb
# 57        88.5         cc66e7ba
# 58        89.2         352ce4a5
# 59        99.8         06b23cfa
